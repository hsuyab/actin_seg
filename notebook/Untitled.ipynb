# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import sys
#setting the path to scripts folder
sys.path.append("/Users/hsuyab/Documents/GitHub/actin_seg/scripts")

# %%
import hash_filepath as hfp
from soaxLogs_to_image import text_path_to_image as t2i

# %%
import os

# %%
directory = (
        "/Users/hsuyab/Documents/Spring 2024/"
        "RA Staiger/SOAX project/Atharva/"
        "SOAX analysis/soax_raw_output_all_files_gray 121923/"
    )

filename_hashtable = hfp.create_filename_hashtable(directory)
# print(filename_hashtable)

# %%
# list(filename_hashtable.keys())[0]
#('AB(101)', (0.02, 0.8))

# %%
ridge_ab = 0.016
stretch_ab = 0.7

ridge_bb = 0.018
stretch_bb = 0.7

# %%
list_of_filenames = list(set([i[0] for i in list(filename_hashtable.keys()) ]))

# %%
for i in list(filename_hashtable.keys()):
    if 'AB(68)' in i[0]:
        print(i)
# Out:
# ('AB(68)', (0.01, 0.3))
# ('AB(68)', (0.01, 0.4))

# %%
filenames_ab = [i for i in list_of_filenames if 'AB' in i]
filenames_bb = [i for i in list_of_filenames if 'BB' in i]
assert len(filenames_ab)==len(filenames_bb)

# %%
# Directory path to check/create
directory_path_ab = '/Users/hsuyab/Documents/GitHub/actin_seg/images/file_AB/'

# Check if the directory exists
if not os.path.exists(directory_path):
    # Create the directory and any missing parent directories
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")
# Out:
# Directory '/Users/hsuyab/Documents/GitHub/actin_seg/images/file_BB/' already exists.

# %%
# Directory path to check/create
directory_path_bb = '/Users/hsuyab/Documents/GitHub/actin_seg/images/file_BB/'

# Check if the directory exists
if not os.path.exists(directory_path):
    # Create the directory and any missing parent directories
    os.makedirs(directory_path)
    print(f"Directory '{directory_path}' created successfully.")
else:
    print(f"Directory '{directory_path}' already exists.")
# Out:
# Directory '/Users/hsuyab/Documents/GitHub/actin_seg/images/file_BB/' already exists.

# %%
filenames_ab
# Out:
# ['AB(68)',
#  'AB(101)',
#  'AB(24)',
#  'AB(51)',
#  'AB(31)',
#  'AB(12)',
#  'AB(5)',
#  'AB(64)',
#  'AB(104)',
#  'AB(11)']

# %%
# filename_hashtable[('AB(68)', ('0.016', '0.7'))]

# %%
# for fi in filenames_ab:
#     fetch_file = (fi, (ridge_ab, stretch_ab))
#     # print(fetch_file)
#     try:
#         img_file = t2i(filename_hashtable[fetch_file])
#         file_save_loc = f"/Users/hsuyab/Documents/GitHub/actin_seg/images/file_AB/{fi}.png"
#         print('Ok')
#         plt.savefig(file_save_loc, img_file, cmap="gray")
#     except KeyError:
#         print(f"The key is not found in the dictionary for {fi}")

# %%
filenames_ab
# Out:
# ['AB(68)',
#  'AB(101)',
#  'AB(24)',
#  'AB(51)',
#  'AB(31)',
#  'AB(12)',
#  'AB(5)',
#  'AB(64)',
#  'AB(104)',
#  'AB(11)']

# %%
# only AB(68) is not there
# fi = 'AB(68)'
# fetch_file = (fi, (0.016, 0.7))
# img_file = t2i(filename_hashtable[fetch_file])
# plt.imshow(img_file, cmap='gray')
# file_save_loc = f"/Users/hsuyab/Documents/GitHub/actin_seg/images/file_AB/{fi}.png"
# plt.imsave(file_save_loc, img_file, cmap="gray")

# %%
list(enumerate(filenames_bb))
# Out:
# [(0, 'BB(54)'),
#  (1, 'BB(18)'),
#  (2, 'BB(20)'),
#  (3, 'BB(17)'),
#  (4, 'BB(26)'),
#  (5, 'BB(109)'),
#  (6, 'BB(4)'),
#  (7, 'BB(12)'),
#  (8, 'BB(62)'),
#  (9, 'BB(59)')]

# %%
fi = filenames_bb[9]
fetch_file = (fi, (0.018, 0.7))
img_file = t2i(filename_hashtable[fetch_file])
plt.imshow(img_file, cmap='gray')
file_save_loc = f"/Users/hsuyab/Documents/GitHub/actin_seg/images/file_BB/{fi}.png"
plt.title(f"SOAX_{fi}_ridge_{ridge_bb}_stretch_{stretch_bb}")
plt.imsave(file_save_loc, img_file, cmap="gray")

# %%
# plt.savefig(file_save_loc, img_file, cmap="gray")

# plt.imshow(t2i(filename_hashtable[('AB(101)', (0.02, 0.8))]), cmap="gray")
# plt.title(f"AB(101) ridge:{0.02} stretch:{0.8}")
# plt.save(

# %%
# #process the list of list data and convert it into a list of lists of floats
# def actin_data_process(x):
#     data = []
#     for i in x:
#         if '#' in i[0]:
#             pass
#         else: 
#             data.append([float(k.strip()) for k in i])
    
#     return data

# #read the text file from text_path
# with open(text_path, 'r') as f:
#     lines = f.readlines()

# #find the locations of lines that have '#' in them and store the index for next line in a list
# hash_lines = []
# for i, line in enumerate(lines):
#     if '#' in line:
#         hash_lines.append(i+1)

# #now store the data from the lines starting from the index in the hash_lines list till the next index in the hash_lines list
# # using [i.split() for i in lines[hash_lines[0]:hash_lines[1]]] and then convert the data in a every list to a float
# # and store it in a actin dictionary
# actin = {}
# actin_num = 1
# for i in range(len(hash_lines)-1):
    
#     if i == len(hash_lines)-1:
#         actin_data = []
#         for l in [i.split() for i in lines[hash_lines[i]:]]:
#             if int(l[0].strip()) == actin_num: 
#                 actin_data.append(l)
#     else:
#         actin_data = [i.split() for i in lines[hash_lines[i]:hash_lines[i+1]]]
    
#     actin[i] = actin_data_process(actin_data)
#     actin_num+=1

# %%
from glob import glob

# %%
gt_op_path = "/Users/hsuyab/Documents/Spring 2024/RA Staiger/SOAX project/Atharva/SOAX analysis/SOAX ground truth csvs 121923/"
soax_op_path = "/Users/hsuyab/Documents/Spring 2024/RA Staiger/SOAX project/Atharva/SOAX analysis/SOAX output csvs gray 121923/"

# %%
path_ab_5_gt = [i for i in glob(gt_op_path+"*") if 'AB(5)' in i]
print(path_ab_5)
# Out:
# ['/Users/hsuyab/Documents/Spring 2024/RA Staiger/SOAX project/Atharva/SOAX analysis/SOAX ground truth csvs 121923/AB(5).csv']

# %%
for x in glob(soax_op_path+"AB(5)/*"):
    if str(ridge_ab) in x and str(stretch_ab) in x:
        path_ab_5_soax = x

# %%
import pandas as pd

# %%
dfsx = pd.read_excel(path_ab_5_soax)
dfgt = pd.read_csv(path_ab_5_gt[0])

# %%
dfgt.head()
# Out:
#       Area       Mean     StdDev       Mode     Median  Skew  Kurt  Length
# 0  1    88  43116.342  12326.061  65448.673  41719.211     0     0  89.260
# 1  2    83  47458.071  12514.809  63449.014  49456.750     0     0  83.944
# 2  3    23  24923.727   3374.942  24999.466  25668.307     0     0  22.813
# 3  4    33  20945.553   4555.286  15377.939  19312.600     0     0  33.133
# 4  5    24  21943.872   3184.305  16265.908  22405.605     0     0  24.052

# %%
dfsx.head()
# Out:
#    Snake Index  Average FG Intensity  Average BG Intensity  \
# 0            0          32318.099254          21039.066418
# 1            1          43318.383505          29699.622680
# 2            2          64864.810000          39346.744545
# 3            3          57268.556452          37054.404839
# 4            4          44882.987097          28018.529032
#
#    Median FG Intensity  Median BG Intensity  Euclidean Distance  \
# 0             28829.75             20449.75          120.441867
# 1             37945.30             28997.55          102.461023
# 2             65535.00             39607.45          101.827788
# 3             59025.20             35879.15           59.268207
# 4             43060.55             28953.45           59.714397
#
#    Snake Body Length  Convolutedness
# 0                134        1.112570
# 1                194        1.893403
# 2                110        1.080255
# 3                 62        1.046092
# ...

# %%
dfsx.columns
# Out:
# Index(['Snake Index', 'Average FG Intensity', 'Average BG Intensity',
#        'Median FG Intensity', 'Median BG Intensity', 'Euclidean Distance',
#        'Snake Body Length', 'Convolutedness'],
#       dtype='object')

# %%
dfsx[['Snake Body Length']].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import seaborn as sns

# %%
sns.kdeplot(dfsx, x='Snake Body Length')
plt.title("Actin Length Distribution (SOAX Output)")
plt.show()

# %%
dfgt['Length']
# Out:
# 0     89.260
# 1     83.944
# 2     22.813
# 3     33.133
# 4     24.052
#        ...
# 79     5.959
# 80    17.191
# 81     9.572
# 82     7.531
# 83    55.261
# Name: Length, Length: 84, dtype: float64

# %%
sns.kdeplot(dfgt, x='Length')
plt.title("Actin Length Distribution (Ground Truth")
plt.show()

# %%
plt.figure(figsize=(8, 6))  # Define the size of the figure
sns.kdeplot(dfgt['Length'], label='GT', fill=True)  # Plot KDE for data1 with label
sns.kdeplot(dfsx['Snake Body Length'], label='SX', fill=True)  # Plot KDE for data2 with label
# Adding title and labels
plt.title('KDE Plot for Length: Ground Truth and SOAX Output For AB(5)')
plt.xlabel('Actin Length')
plt.ylabel('Density')
# Show legend
plt.legend()
# Display the plot
plt.show()

# %%
dfsx.columns
# Out:
# Index(['Snake Index', 'Average FG Intensity', 'Average BG Intensity',
#        'Median FG Intensity', 'Median BG Intensity', 'Euclidean Distance',
#        'Snake Body Length', 'Convolutedness'],
#       dtype='object')

# %%
dfsx.head()
# Out:
#    Snake Index  Average FG Intensity  Average BG Intensity  \
# 0            0          32318.099254          21039.066418
# 1            1          43318.383505          29699.622680
# 2            2          64864.810000          39346.744545
# 3            3          57268.556452          37054.404839
# 4            4          44882.987097          28018.529032
#
#    Median FG Intensity  Median BG Intensity  Euclidean Distance  \
# 0             28829.75             20449.75          120.441867
# 1             37945.30             28997.55          102.461023
# 2             65535.00             39607.45          101.827788
# 3             59025.20             35879.15           59.268207
# 4             43060.55             28953.45           59.714397
#
#    Snake Body Length  Convolutedness
# 0                134        1.112570
# 1                194        1.893403
# 2                110        1.080255
# 3                 62        1.046092
# ...

# %%
dfgt[['Length']].plot(kind='hist')
# dfsx[['Snake Body Length']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfsx[['Snake Body Length']].describe()
# Out:
#        Snake Body Length
# count          67.000000
# mean           35.701493
# std            39.607550
# min             6.000000
# 25%            10.000000
# 50%            21.000000
# 75%            44.000000
# max           194.000000

# %%
plt.figure(figsize=(8, 6))  # Define the size of the figure
sns.kdeplot(dfgt['Mean'], label='GT', fill=True)  # Plot KDE for data1 with label
sns.kdeplot(dfsx['Average FG Intensity'], label='SX', fill=True)  # Plot KDE for data2 with label
# Adding title and labels
plt.title('KDE Plot for Intensity: Ground Truth and SOAX Output For AB(5)')
plt.xlabel('Filament Intensity')
plt.ylabel('Density')
# Show legend
plt.legend()
# Display the plot
plt.show()
